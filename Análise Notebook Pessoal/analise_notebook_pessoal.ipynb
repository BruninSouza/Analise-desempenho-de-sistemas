# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Análise Notebook Pessoal
#
# Análise feita usando meu notebook pessoal. Configurações da máquina:
# - SO: Windows 10 64bits
# - Modelo de hardware: Aspire A315-41
# - Memória ram: 12 GB DDR4
# - Processador: AMD Ryzen 5 2500U
# - Placa de vídeo: Radeon Vega Mobile Gfx 2.00 GHz integrada no processador
# - Disco rígido: 790 GB HDD

# %% [markdown]
# ## Procurando números primos

# %% [markdown]
# ### Criando Dataset

# %%
df_primos = pd.read_csv("dataset-primos.csv")

# %% [markdown]
# ### Reordenando o Dataset pelo número de threads

# %%
df_primos = df_primos.sort_values(by="NumThreads")

# Salvar o dataset ordenado em um arquivo CSV
output_file = "dataset-primos.csv"
df_primos.to_csv(output_file, index=False)

# Salvando dataset no excel
df_primos.to_excel('dataset_primos.xlsx')

# %% [markdown]
# ### QUESTÃO 1

# %% [markdown]
# #### a)

# %%
# Ordenar os dados pelo número máximo de primos
df_primos_qt_01 = df_primos[df_primos["NumeroMaximo"]==110000]
uso_cpu = df_primos_qt_01.sort_values(by="MeanUtilization", ascending=True)

uso_cpu = uso_cpu[["NumThreads", "MeanUtilization"]]
display(uso_cpu)
# Out:
#     NumThreads  MeanUtilization
# 0            2         0.329480
# 1            4         0.569866
# 4            6         0.812349
# 57          40         0.976138
# 29          22         0.977020
# 37          36         0.985635
# 34          32         0.988988
# 33          30         0.992304
# 28          20         0.992901
# 31          26         0.996644
# 32          28         0.996740
# 35          34         0.997525
# 30          24         0.997940
# 26          16         0.998341
# 27          18         0.998906
# 24          12         0.998976
# 25          14         0.999059
# 56          38         0.999252
# 22           8         1.000000
# 23          10         1.000000

# %% [markdown]
# Embora menos potente que a máquina do laboratório, é possível perceber um resultado parecido  com o anterior, visto uma escala proporcional de cerca de 25% no uso da CPU quando se aumenta de 2 em 2 o número de threads. Entretanto, ao chegar a marca de 8 threads o uso da CPU se estabiliza entre 100% e 97%.
#
# Os resultados iniciais apresentam um bom gerenciamento de uso da CPU, entretanto, conforme o número de threads aumenta, o uso de CPU também aumenta e tende a atingir um limite de 100%, demonstrando não ser mais capaz de gerar ganhos substanciais.
#
# O Gráfico 1 demonstra isso:

# %% [markdown]
# ##### Gráfico 1

# %%
# Convertendo valores para porcentagem
df_primos_qt_01["MeanUtilizationPercent"] = df_primos_qt_01["MeanUtilization"] * 100

plt.figure(figsize=(12, 10))
bars = plt.barh(df_primos_qt_01["NumThreads"], df_primos_qt_01["MeanUtilizationPercent"], color='purple')

for bar in bars:
    plt.text(
        bar.get_width() + 1,  # Posição horizontal (após a barra)
        bar.get_y() + bar.get_height() / 2,  # Centralizado verticalmente
        f'{bar.get_width():.1f}%',  # Valor formatado como porcentagem
        va='center'
    )

num_threads = df_primos_qt_01["NumThreads"]

plt.yticks(ticks=range(min(num_threads), max(num_threads) + 1, 2))
plt.title("Relação entre número de threads e uso de CPU (em %)")
plt.xlabel("Uso médio da CPU (%)")
plt.ylabel("Número de Threads")

plt.savefig('grafico_uso_cpu.jpeg', format='jpeg', bbox_inches='tight')

plt.show()
# Out:
# C:\Users\bruns\AppData\Local\Temp\ipykernel_16544\749189394.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_primos_qt_01["MeanUtilizationPercent"] = df_primos_qt_01["MeanUtilization"] * 100

# %% [markdown]
# #### b)

# %%
# Ordenar os dados pelo número de threads
df_primos_qt_01 = df_primos[df_primos["NumeroMaximo"]==110000]
temp_total_exec = df_primos_qt_01.sort_values(by="ElapsedTime", ascending=True)

# Exibir apenas as colunas desejadas
temp_total_exec = temp_total_exec[["NumThreads", "MeanUtilization","ElapsedTime"]]
display(temp_total_exec.style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3093">
#   <thead>
#     <tr>
#       <th id="T_a3093_level0_col0" class="col_heading level0 col0" >NumThreads</th>
#       <th id="T_a3093_level0_col1" class="col_heading level0 col1" >MeanUtilization</th>
#       <th id="T_a3093_level0_col2" class="col_heading level0 col2" >ElapsedTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a3093_row0_col0" class="data row0 col0" >34</td>
#       <td id="T_a3093_row0_col1" class="data row0 col1" >0.997525</td>
#       <td id="T_a3093_row0_col2" class="data row0 col2" >3596</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_a3093_row1_col1" class="data row1 col1" >0.812349</td>
#       <td id="T_a3093_row1_col2" class="data row1 col2" >3598</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row2_col0" class="data row2 col0" >28</td>
#       <td id="T_a3093_row2_col1" class="data row2 col1" >0.996740</td>
#       <td id="T_a3093_row2_col2" class="data row2 col2" >3602</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_a3093_row3_col1" class="data row3 col1" >0.998976</td>
#       <td id="T_a3093_row3_col2" class="data row3 col2" >3618</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row4_col0" class="data row4 col0" >36</td>
#       <td id="T_a3093_row4_col1" class="data row4 col1" >0.985635</td>
#       <td id="T_a3093_row4_col2" class="data row4 col2" >3620</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row5_col0" class="data row5 col0" >20</td>
#       <td id="T_a3093_row5_col1" class="data row5 col1" >0.992901</td>
#       <td id="T_a3093_row5_col2" class="data row5 col2" >3629</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_a3093_row6_col1" class="data row6 col1" >0.998341</td>
#       <td id="T_a3093_row6_col2" class="data row6 col2" >3632</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row7_col0" class="data row7 col0" >32</td>
#       <td id="T_a3093_row7_col1" class="data row7 col1" >0.988988</td>
#       <td id="T_a3093_row7_col2" class="data row7 col2" >3632</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_a3093_row8_col1" class="data row8 col1" >1.000000</td>
#       <td id="T_a3093_row8_col2" class="data row8 col2" >3638</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row9_col0" class="data row9 col0" >38</td>
#       <td id="T_a3093_row9_col1" class="data row9 col1" >0.999252</td>
#       <td id="T_a3093_row9_col2" class="data row9 col2" >3640</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row10_col0" class="data row10 col0" >14</td>
#       <td id="T_a3093_row10_col1" class="data row10 col1" >0.999059</td>
#       <td id="T_a3093_row10_col2" class="data row10 col2" >3642</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row11_col0" class="data row11 col0" >30</td>
#       <td id="T_a3093_row11_col1" class="data row11 col1" >0.992304</td>
#       <td id="T_a3093_row11_col2" class="data row11 col2" >3644</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row12_col0" class="data row12 col0" >18</td>
#       <td id="T_a3093_row12_col1" class="data row12 col1" >0.998906</td>
#       <td id="T_a3093_row12_col2" class="data row12 col2" >3646</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row13_col0" class="data row13 col0" >24</td>
#       <td id="T_a3093_row13_col1" class="data row13 col1" >0.997940</td>
#       <td id="T_a3093_row13_col2" class="data row13 col2" >3667</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row14_col0" class="data row14 col0" >22</td>
#       <td id="T_a3093_row14_col1" class="data row14 col1" >0.977020</td>
#       <td id="T_a3093_row14_col2" class="data row14 col2" >3678</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row15_col0" class="data row15 col0" >40</td>
#       <td id="T_a3093_row15_col1" class="data row15 col1" >0.976138</td>
#       <td id="T_a3093_row15_col2" class="data row15 col2" >3683</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row16_col0" class="data row16 col0" >26</td>
#       <td id="T_a3093_row16_col1" class="data row16 col1" >0.996644</td>
#       <td id="T_a3093_row16_col2" class="data row16 col2" >3686</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row17_col0" class="data row17 col0" >10</td>
#       <td id="T_a3093_row17_col1" class="data row17 col1" >1.000000</td>
#       <td id="T_a3093_row17_col2" class="data row17 col2" >3704</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row18_col0" class="data row18 col0" >4</td>
#       <td id="T_a3093_row18_col1" class="data row18 col1" >0.569866</td>
#       <td id="T_a3093_row18_col2" class="data row18 col2" >4659</td>
#     </tr>
#     <tr>
#       <td id="T_a3093_row19_col0" class="data row19 col0" >2</td>
#       <td id="T_a3093_row19_col1" class="data row19 col1" >0.329480</td>
#       <td id="T_a3093_row19_col2" class="data row19 col2" >7245</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Inicialmente o aumento do número de threads reduz bastante o tempo de execução do código, indicando uma boa escalabilidade, entretanto, isso se dá apenas até o número de 6 threads, após isso os tempos de execução tendem a variar bastante, indicando um péssimo desempenho e mal gerenciamento dos recursos da máquina.
#
# A seguir o Gráfico 2 que exemplifica bem isso:

# %% [markdown]
# ##### Gráfico 2

# %%
plt.figure(figsize=(12, 10))
bars = plt.barh(df_primos_qt_01["NumThreads"], df_primos_qt_01["ElapsedTime"], color='orange')

# Adicionando os valores nas barras
for bar in bars:
    plt.text(
        bar.get_width() + 1,  # Posição horizontal (após a barra)
        bar.get_y() + bar.get_height() / 2,  # Centralizado verticalmente
        f'{bar.get_width()}',  # Valor formatado como porcentagem
        va='center'
    )

# Espaçamento entre as barras
num_threads = df_primos_qt_01["NumThreads"]
plt.yticks(ticks=range(min(num_threads), max(num_threads) + 1, 2))

plt.title("Relação entre número de threas e tempo de execução (ms)")
plt.xlabel("Tempo de execução (ms)")
plt.ylabel("Número de Threads")

plt.savefig('grafico_temp_execucao.jpeg', format='jpeg', bbox_inches='tight')

plt.show()

# %% [markdown]
# #### c)

# %% [markdown]
# Foi selecionado o número de 6 e 36 threads, pois demonstraram um ótimo tempo de execução e um bom gerenciamento de uso de CPU, sendo assim, suportam executar o programa com quantidade de números primos maior. Além disso, gostaria de comprovar qual deles é o mais eficiente.

# %% [markdown]
# ### QUESTÃO 2

# %% [markdown]
# #### a)

# %% [markdown]
# ##### usando 6 threads

# %%
# Ordenar os dados pelo número de threads
df_primos_qt_02 = df_primos[df_primos["NumThreads"]==6]
temp_exec = df_primos_qt_02.sort_values(by="ElapsedTime", ascending=True)

temp_exec = temp_exec[["NumThreads","NumeroMaximo","ElapsedTime"]]
temp_exec = temp_exec.reset_index(drop=True)
display(temp_exec.style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_70e65">
#   <thead>
#     <tr>
#       <th id="T_70e65_level0_col0" class="col_heading level0 col0" >NumThreads</th>
#       <th id="T_70e65_level0_col1" class="col_heading level0 col1" >NumeroMaximo</th>
#       <th id="T_70e65_level0_col2" class="col_heading level0 col2" >ElapsedTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_70e65_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_70e65_row0_col1" class="data row0 col1" >10000</td>
#       <td id="T_70e65_row0_col2" class="data row0 col2" >63</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_70e65_row1_col1" class="data row1 col1" >20000</td>
#       <td id="T_70e65_row1_col2" class="data row1 col2" >172</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_70e65_row2_col1" class="data row2 col1" >30000</td>
#       <td id="T_70e65_row2_col2" class="data row2 col2" >328</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_70e65_row3_col1" class="data row3 col1" >40000</td>
#       <td id="T_70e65_row3_col2" class="data row3 col2" >540</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_70e65_row4_col1" class="data row4 col1" >50000</td>
#       <td id="T_70e65_row4_col2" class="data row4 col2" >856</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_70e65_row5_col1" class="data row5 col1" >60000</td>
#       <td id="T_70e65_row5_col2" class="data row5 col2" >1235</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_70e65_row6_col1" class="data row6 col1" >70000</td>
#       <td id="T_70e65_row6_col2" class="data row6 col2" >1622</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_70e65_row7_col1" class="data row7 col1" >80000</td>
#       <td id="T_70e65_row7_col2" class="data row7 col2" >2117</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row8_col0" class="data row8 col0" >6</td>
#       <td id="T_70e65_row8_col1" class="data row8 col1" >90000</td>
#       <td id="T_70e65_row8_col2" class="data row8 col2" >2698</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row9_col0" class="data row9 col0" >6</td>
#       <td id="T_70e65_row9_col1" class="data row9 col1" >100000</td>
#       <td id="T_70e65_row9_col2" class="data row9 col2" >3230</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row10_col0" class="data row10 col0" >6</td>
#       <td id="T_70e65_row10_col1" class="data row10 col1" >110000</td>
#       <td id="T_70e65_row10_col2" class="data row10 col2" >3598</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row11_col0" class="data row11 col0" >6</td>
#       <td id="T_70e65_row11_col1" class="data row11 col1" >200000</td>
#       <td id="T_70e65_row11_col2" class="data row11 col2" >12419</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row12_col0" class="data row12 col0" >6</td>
#       <td id="T_70e65_row12_col1" class="data row12 col1" >300000</td>
#       <td id="T_70e65_row12_col2" class="data row12 col2" >28883</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row13_col0" class="data row13 col0" >6</td>
#       <td id="T_70e65_row13_col1" class="data row13 col1" >400000</td>
#       <td id="T_70e65_row13_col2" class="data row13 col2" >53838</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row14_col0" class="data row14 col0" >6</td>
#       <td id="T_70e65_row14_col1" class="data row14 col1" >500000</td>
#       <td id="T_70e65_row14_col2" class="data row14 col2" >85071</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row15_col0" class="data row15 col0" >6</td>
#       <td id="T_70e65_row15_col1" class="data row15 col1" >600000</td>
#       <td id="T_70e65_row15_col2" class="data row15 col2" >126244</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row16_col0" class="data row16 col0" >6</td>
#       <td id="T_70e65_row16_col1" class="data row16 col1" >700000</td>
#       <td id="T_70e65_row16_col2" class="data row16 col2" >154851</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row17_col0" class="data row17 col0" >6</td>
#       <td id="T_70e65_row17_col1" class="data row17 col1" >800000</td>
#       <td id="T_70e65_row17_col2" class="data row17 col2" >201099</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row18_col0" class="data row18 col0" >6</td>
#       <td id="T_70e65_row18_col1" class="data row18 col1" >900000</td>
#       <td id="T_70e65_row18_col2" class="data row18 col2" >258341</td>
#     </tr>
#     <tr>
#       <td id="T_70e65_row19_col0" class="data row19 col0" >6</td>
#       <td id="T_70e65_row19_col1" class="data row19 col1" >1000000</td>
#       <td id="T_70e65_row19_col2" class="data row19 col2" >315303</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# O resultado demonstra claramente um aumento, entretando, não se dá de maneira linear, evidenciando a complexidade da tarefa dada pelo algoritmo, limitações de paralelização e um maior consumo dos recursos do sistema.
#
# Os Gráficos 3 e 4 evidenciam isso.

# %% [markdown]
# ##### Gráficos 3 e 4

# %%
df_intervalo1 = temp_exec[temp_exec["NumeroMaximo"] <= 110000]  # Valores menores ou iguais a 110000
df_intervalo2 = temp_exec[temp_exec["NumeroMaximo"] >= 110000]  # Valores maiores ou iguais a 110000

df_intervalo1 = df_intervalo1.sort_values(by="ElapsedTime", ascending=True)

# Gerar o primeiro gráfico
plt.figure(figsize=(10, 6))
plt.plot(df_intervalo1["NumeroMaximo"], df_intervalo1["ElapsedTime"], color='black', label='Linha de Execução')
plt.scatter(df_intervalo1["NumeroMaximo"], df_intervalo1["ElapsedTime"], color='red', zorder=5)
plt.xlabel("Número Máximo (100k)", fontsize=12)
plt.ylabel("Tempo de Execução (s)", fontsize=12)
plt.title("Tempo de Execução vs Número Máximo (10.000 a 110.000)", fontsize=14)

plt.savefig('grafico_escalabilidade_exec_01.jpeg', format='jpeg', bbox_inches='tight')

plt.show()

df_intervalo2 = df_intervalo2.sort_values(by="ElapsedTime", ascending=True)

# Gerar o segundo gráfico
plt.figure(figsize=(10, 6))
plt.plot(df_intervalo2["NumeroMaximo"], df_intervalo2["ElapsedTime"], color='black', label='Linha de Execução')
plt.scatter(df_intervalo2["NumeroMaximo"], df_intervalo2["ElapsedTime"], color='red', zorder=5)
plt.xlabel("Número Máximo (100k)", fontsize=12)
plt.ylabel("Tempo de Execução (s)", fontsize=12)
plt.title("Tempo de Execução vs Número Máximo (110.000 a 1.100.000)", fontsize=14)

plt.savefig('grafico_escalabilidade_exec_02.jpeg', format='jpeg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ##### Usando 36 threads

# %%
# Ordenar os dados pelo número de threads
df_primos_qt_02 = df_primos[df_primos["NumThreads"]==36]
temp_exec = df_primos_qt_02.sort_values(by="ElapsedTime", ascending=True)

temp_exec = temp_exec[["NumThreads","NumeroMaximo","ElapsedTime"]]
display(temp_exec.style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_c6a1f">
#   <thead>
#     <tr>
#       <th id="T_c6a1f_level0_col0" class="col_heading level0 col0" >NumThreads</th>
#       <th id="T_c6a1f_level0_col1" class="col_heading level0 col1" >NumeroMaximo</th>
#       <th id="T_c6a1f_level0_col2" class="col_heading level0 col2" >ElapsedTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c6a1f_row0_col0" class="data row0 col0" >36</td>
#       <td id="T_c6a1f_row0_col1" class="data row0 col1" >10000</td>
#       <td id="T_c6a1f_row0_col2" class="data row0 col2" >82</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row1_col0" class="data row1 col0" >36</td>
#       <td id="T_c6a1f_row1_col1" class="data row1 col1" >20000</td>
#       <td id="T_c6a1f_row1_col2" class="data row1 col2" >151</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row2_col0" class="data row2 col0" >36</td>
#       <td id="T_c6a1f_row2_col1" class="data row2 col1" >30000</td>
#       <td id="T_c6a1f_row2_col2" class="data row2 col2" >304</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row3_col0" class="data row3 col0" >36</td>
#       <td id="T_c6a1f_row3_col1" class="data row3 col1" >40000</td>
#       <td id="T_c6a1f_row3_col2" class="data row3 col2" >530</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row4_col0" class="data row4 col0" >36</td>
#       <td id="T_c6a1f_row4_col1" class="data row4 col1" >50000</td>
#       <td id="T_c6a1f_row4_col2" class="data row4 col2" >801</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row5_col0" class="data row5 col0" >36</td>
#       <td id="T_c6a1f_row5_col1" class="data row5 col1" >60000</td>
#       <td id="T_c6a1f_row5_col2" class="data row5 col2" >1195</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row6_col0" class="data row6 col0" >36</td>
#       <td id="T_c6a1f_row6_col1" class="data row6 col1" >70000</td>
#       <td id="T_c6a1f_row6_col2" class="data row6 col2" >1570</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row7_col0" class="data row7 col0" >36</td>
#       <td id="T_c6a1f_row7_col1" class="data row7 col1" >80000</td>
#       <td id="T_c6a1f_row7_col2" class="data row7 col2" >2022</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row8_col0" class="data row8 col0" >36</td>
#       <td id="T_c6a1f_row8_col1" class="data row8 col1" >90000</td>
#       <td id="T_c6a1f_row8_col2" class="data row8 col2" >2484</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row9_col0" class="data row9 col0" >36</td>
#       <td id="T_c6a1f_row9_col1" class="data row9 col1" >100000</td>
#       <td id="T_c6a1f_row9_col2" class="data row9 col2" >3054</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row10_col0" class="data row10 col0" >36</td>
#       <td id="T_c6a1f_row10_col1" class="data row10 col1" >110000</td>
#       <td id="T_c6a1f_row10_col2" class="data row10 col2" >3620</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row11_col0" class="data row11 col0" >36</td>
#       <td id="T_c6a1f_row11_col1" class="data row11 col1" >200000</td>
#       <td id="T_c6a1f_row11_col2" class="data row11 col2" >12100</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row12_col0" class="data row12 col0" >36</td>
#       <td id="T_c6a1f_row12_col1" class="data row12 col1" >300000</td>
#       <td id="T_c6a1f_row12_col2" class="data row12 col2" >27030</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row13_col0" class="data row13 col0" >36</td>
#       <td id="T_c6a1f_row13_col1" class="data row13 col1" >400000</td>
#       <td id="T_c6a1f_row13_col2" class="data row13 col2" >47757</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row14_col0" class="data row14 col0" >36</td>
#       <td id="T_c6a1f_row14_col1" class="data row14 col1" >500000</td>
#       <td id="T_c6a1f_row14_col2" class="data row14 col2" >74153</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row15_col0" class="data row15 col0" >36</td>
#       <td id="T_c6a1f_row15_col1" class="data row15 col1" >600000</td>
#       <td id="T_c6a1f_row15_col2" class="data row15 col2" >107040</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row16_col0" class="data row16 col0" >36</td>
#       <td id="T_c6a1f_row16_col1" class="data row16 col1" >700000</td>
#       <td id="T_c6a1f_row16_col2" class="data row16 col2" >145427</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row17_col0" class="data row17 col0" >36</td>
#       <td id="T_c6a1f_row17_col1" class="data row17 col1" >800000</td>
#       <td id="T_c6a1f_row17_col2" class="data row17 col2" >190335</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row18_col0" class="data row18 col0" >36</td>
#       <td id="T_c6a1f_row18_col1" class="data row18 col1" >900000</td>
#       <td id="T_c6a1f_row18_col2" class="data row18 col2" >239610</td>
#     </tr>
#     <tr>
#       <td id="T_c6a1f_row19_col0" class="data row19 col0" >36</td>
#       <td id="T_c6a1f_row19_col1" class="data row19 col1" >1000000</td>
#       <td id="T_c6a1f_row19_col2" class="data row19 col2" >295407</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Com 36 threads, o tempo de execução é significativamente menor, mas o ganho percentual diminui conforme o valor máximo usado aumenta, possivelmente devido à saturação da paralelização e limitações do algoritmo. Assim como com 6 threads, seu aumento no tempo de execução ocorre de maneira não-linear.
#
# Os Gráficos 5 e 7 nos mostram visualmente como ocorre:

# %% [markdown]
# ##### Gráficos 5 e 6

# %%
df_intervalo1 = temp_exec[temp_exec["NumeroMaximo"] <= 110000]  # Valores menores ou iguais a 110000
df_intervalo2 = temp_exec[temp_exec["NumeroMaximo"] >= 110000]  # Valores maiores ou iguais a 110000

df_intervalo1 = df_intervalo1.sort_values(by="ElapsedTime", ascending=True)

# Gerar o primeiro gráfico
plt.figure(figsize=(10, 6))
plt.plot(df_intervalo1["NumeroMaximo"], df_intervalo1["ElapsedTime"], color='green', label='Linha de Execução')
plt.scatter(df_intervalo1["NumeroMaximo"], df_intervalo1["ElapsedTime"], color='blue', zorder=5)
plt.xlabel("Número Máximo (100k)", fontsize=12)
plt.ylabel("Tempo de Execução (s)", fontsize=12)
plt.title("Tempo de Execução vs Número Máximo (10.000 a 110.000)", fontsize=14)

plt.savefig('grafico_escalabilidade_exec_03.jpeg', format='jpeg', bbox_inches='tight')

plt.show()

df_intervalo2 = df_intervalo2.sort_values(by="ElapsedTime", ascending=True)

# Gerar o segundo gráfico
plt.figure(figsize=(10, 6))
plt.plot(df_intervalo2["NumeroMaximo"], df_intervalo2["ElapsedTime"], color='green', label='Linha de Execução')
plt.scatter(df_intervalo2["NumeroMaximo"], df_intervalo2["ElapsedTime"], color='blue', zorder=5)
plt.xlabel("Número Máximo (100k)", fontsize=12)
plt.ylabel("Tempo de Execução (s)", fontsize=12)
plt.title("Tempo de Execução vs Número Máximo (110.000 a 1.100.000)", fontsize=14)

plt.savefig('grafico_escalabilidade_exec_04.jpeg', format='jpeg', bbox_inches='tight')

plt.show()

# %% [markdown]
# #### b)

# %% [markdown]
# Embora o programa mostre alguma escalabilidade com o aumento do número de threads inicialmente, ele não é totalmente escalável para grandes volumes de trabalho devido à saturação da paralelização e à complexidade algorítmica.

# %% [markdown]
# ## Fazendo acessos à memória

# %% [markdown]
# ### Criando dataset

# %%
df_memoria = pd.read_csv("dataset-memoria.csv")

# %% [markdown]
# ### Reordenando o Dataset pelo tamanho da memória usada

# %%
df_memoria = df_memoria.sort_values(by="KBinMemory")

# Salvar o dataset ordenado em um arquivo CSV
output_file = "dataset-memoria.csv"
df_memoria.to_csv(output_file, index=False)

# Salvando dataset no excel
df_memoria.to_excel('dataset_memoria.xlsx')

# %% [markdown]
# ### Questão 1

# %% [markdown]
# #### a)

# %%
tempo_busca = df_memoria.sort_values(by="SearchTime",ascending=True)
tempo_busca = tempo_busca[["KBinMemory","SearchTime"]]
display(tempo_busca.style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_fdc9e">
#   <thead>
#     <tr>
#       <th id="T_fdc9e_level0_col0" class="col_heading level0 col0" >KBinMemory</th>
#       <th id="T_fdc9e_level0_col1" class="col_heading level0 col1" >SearchTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fdc9e_row0_col0" class="data row0 col0" >1024</td>
#       <td id="T_fdc9e_row0_col1" class="data row0 col1" >1777</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row1_col0" class="data row1 col0" >10240</td>
#       <td id="T_fdc9e_row1_col1" class="data row1 col1" >5938</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row2_col0" class="data row2 col0" >30720</td>
#       <td id="T_fdc9e_row2_col1" class="data row2 col1" >7070</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row3_col0" class="data row3 col0" >40960</td>
#       <td id="T_fdc9e_row3_col1" class="data row3 col1" >7125</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row4_col0" class="data row4 col0" >20480</td>
#       <td id="T_fdc9e_row4_col1" class="data row4 col1" >7182</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row5_col0" class="data row5 col0" >61440</td>
#       <td id="T_fdc9e_row5_col1" class="data row5 col1" >7219</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row6_col0" class="data row6 col0" >71680</td>
#       <td id="T_fdc9e_row6_col1" class="data row6 col1" >7219</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row7_col0" class="data row7 col0" >51200</td>
#       <td id="T_fdc9e_row7_col1" class="data row7 col1" >7249</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row8_col0" class="data row8 col0" >81920</td>
#       <td id="T_fdc9e_row8_col1" class="data row8 col1" >7328</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row9_col0" class="data row9 col0" >92160</td>
#       <td id="T_fdc9e_row9_col1" class="data row9 col1" >7359</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row10_col0" class="data row10 col0" >102400</td>
#       <td id="T_fdc9e_row10_col1" class="data row10 col1" >7484</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row11_col0" class="data row11 col0" >204800</td>
#       <td id="T_fdc9e_row11_col1" class="data row11 col1" >7609</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row12_col0" class="data row12 col0" >307200</td>
#       <td id="T_fdc9e_row12_col1" class="data row12 col1" >7687</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row13_col0" class="data row13 col0" >409600</td>
#       <td id="T_fdc9e_row13_col1" class="data row13 col1" >8015</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row14_col0" class="data row14 col0" >512000</td>
#       <td id="T_fdc9e_row14_col1" class="data row14 col1" >8109</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row15_col0" class="data row15 col0" >614400</td>
#       <td id="T_fdc9e_row15_col1" class="data row15 col1" >8219</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row16_col0" class="data row16 col0" >716800</td>
#       <td id="T_fdc9e_row16_col1" class="data row16 col1" >8484</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row17_col0" class="data row17 col0" >921600</td>
#       <td id="T_fdc9e_row17_col1" class="data row17 col1" >8952</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row18_col0" class="data row18 col0" >819200</td>
#       <td id="T_fdc9e_row18_col1" class="data row18 col1" >9062</td>
#     </tr>
#     <tr>
#       <td id="T_fdc9e_row19_col0" class="data row19 col0" >1048576</td>
#       <td id="T_fdc9e_row19_col1" class="data row19 col1" >9516</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Assim como o teste com o computador do laboratório, o tempo de busca aumenta com o tamanho do array, mas a taxa de aumento diminui conforme o array cresce, se estabilizando quando alcança valores acima de 10 megabytes. Isso indica que, para arrays menores, o desempenho é mais impactado pela localidade de referência e pelo cache, enquanto para arrays maiores, o gerenciamento de memória e outras otimizações de hardware podem reduzir o impacto do crescimento do array.
#
# Os Gráficos 7 e 8 demonstram isso visualmente:

# %% [markdown]
# ##### Gráficos 7 e 8

# %%
tempo_busca["MBinMemory"] = df_memoria["KBinMemory"] / 1024

# Separando os dados em dois subconjuntos:
df1 = tempo_busca[tempo_busca["MBinMemory"] <= 90]  # Valores de 1 a 90
df2 = tempo_busca[tempo_busca["MBinMemory"] >= 100]  # Valores de 100 até 1024

# Gráfico com valores de 1 a 90
plt.figure(figsize=(12, 8))
bars1 = plt.bar(df1["MBinMemory"], df1["SearchTime"], width=6, color='c')
plt.title("Relação entre tamanho do array e tempo de busca (1 a 90 MB)")
plt.xlabel("Tamanho do array (MB)")
plt.ylabel("Tempo de busca (ms)")
plt.xticks([1] + list(range(10, 91, 10)))

for bar in bars1:
    yval = bar.get_height() 
    plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), 
             ha='center', va='bottom', fontsize=10) 

plt.tight_layout()

plt.savefig('grafico_escalabilidade_array_01.jpeg', format='jpeg', bbox_inches='tight')

plt.show()

# Gráfico com valores de 100 a 1024
plt.figure(figsize=(12, 8))
bars2 = plt.bar(df2["MBinMemory"], df2["SearchTime"], width=50, color='m')
plt.title("Relação entre tamanho do array e tempo de busca (100 a 1024 MB)")
plt.xlabel("Tamanho do array (MB)")
plt.ylabel("Tempo de busca (ms)")
plt.xticks(list(range(100, 1000, 100)) + [1024])
plt.xlim(70, 1054)

for bar in bars2:
    yval = bar.get_height()  
    plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), 
             ha='center', va='bottom', fontsize=10)  
    
plt.savefig('grafico_escalabilidade_array_02.jpeg', format='jpeg', bbox_inches='tight')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #### b)

# %% [markdown]
# Embora o aumento do tempo de busca seja, em geral, previsível, o sistema não é perfeitamente escalável devido a mudanças bruscas no desempenho em certos pontos. Esses saltos podem ser atribuídos a fatores como a transição entre o uso do cache e da memória principal, o impacto do gerenciamento de memória (paginamento e swap), limitações na arquitetura de hardware e a eficiência do algoritmo de busca. Essas variáveis podem causar momentos em que o tempo de busca sofre variações significativas ao aumentar o tamanho do array.
